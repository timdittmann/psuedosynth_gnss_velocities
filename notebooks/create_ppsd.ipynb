# %% [markdown]
# Notebook to explain workflow
#
# PPSD takes in velocities from an ambient event free data set.

# %%
# %run ../bin/noise/ambient2sac.py
# Out:
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/notebooks
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cn29_251_2017.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cn33_251_2017.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_cnc0_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_cotm_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_elma_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_grza_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_hati_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_hsmn_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_isco_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_kios_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_kvtx_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_lafe_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_leme_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_lepa_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_lgc1_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_mana_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_mdwd_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_mom0_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_momi_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_oxum_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p807_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_pne2_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_puje_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_pumo_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_qsec_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_rdct_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_roa0_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_scw2_251_2017.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_spbh_251_2017.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_vrai_317_2017.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p815_023_2018.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cn24_047_2018.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_oxum_048_2018.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_tnat_048_2018.txt not found.
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_tnnx_048_2018.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_tnsj_048_2018.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_tncy_048_2018.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_tnnp_048_2018.txt"
#   a = numpy.loadtxt(velfile)
# ../data/jgr_data/output/ambient_set_2/velocities_cccc_185_2019.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p522_185_2019.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_bsry_187_2019.txt not found.
# too many indices for array: array is 1-dimensional, but 2 were indexed
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cccc_187_2019.txt"
#   a = numpy.loadtxt(velfile)
# ../data/jgr_data/output/ambient_set_2/velocities_chms_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_cpbn_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_hivi_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_islk_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_linj_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_lnmt_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p056_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p091_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p093_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p094_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p462_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p463_187_2019.txt not found.
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_p466_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p467_187_2019.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p464_187_2019.txt"
#   a = numpy.loadtxt(velfile)
# ../data/jgr_data/output/ambient_set_2/velocities_p557_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p558_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p560_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p565_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p567_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p568_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p569_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p570_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p571_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p572_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p579_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p580_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p582_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p583_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p588_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p590_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p591_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p592_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p593_187_2019.txt not found.
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_p596_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p597_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p604_187_2019.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p594_187_2019.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p595_187_2019.txt"
#   a = numpy.loadtxt(velfile)
# ../data/jgr_data/output/ambient_set_2/velocities_p615_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p616_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p617_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p620_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p809_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p810_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p811_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p812_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_ramt_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_rstp_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_shos_187_2019.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_thcp_187_2019.txt not found.
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cn05_007_2020.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_coon_078_2020.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_p133_136_2020.txt not found.
# ../data/jgr_data/output/ambient_set_2/velocities_p649_136_2020.txt not found.
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p132_143_2020.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p627_143_2020.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_crrs_275_2020.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p495_275_2020.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_p507_275_2020.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_cn55_202_2021.txt"
#   a = numpy.loadtxt(velfile)
# /home/ec2-user/pgv_ml/psuedosyn_gnssvel/bin/noise/ambient2sac.py:17: UserWarning: loadtxt: input contained no data: "../data/jgr_data/output/ambient_set_2/velocities_vrai_202_2021.txt"
#   a = numpy.loadtxt(velfile)
# too many indices for array: array is 1-dimensional, but 2 were indexed
# too many indices for array: array is 1-dimensional, but 2 were indexed
# ../data/jgr_data/output/ambient_set_2/velocities_p157_354_2021.txt not found.

# %% [markdown]
# Something about the next script

# %%
# %run ../bin/noise/sac2noise.py
